# %%
# !pip install -r requirements.txt
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# # Explore

# %%
import duckdb

# Load SQL extension
# %load_ext sql

# Initialize 🦆 DuckDB connection
conn = duckdb.connect()

# Import database
# %sql conn --alias duckdb
# %sql IMPORT DATABASE '../../data/nps';
# Out:
# Loading configurations from /workspaces/fundamentals-of-data-transformation-4554074/pyproject.toml.
# Settings changed:
# +--------------+-------+
# |    Config    | value |
# +--------------+-------+
# |   feedback   |  True |
# |  autopandas  |  True |
# | displaylimit |   10  |
# |  displaycon  | False |
# +--------------+-------+
#    Count
# 0    224

# %%
# %%sql
# SHOW ALL TABLES
# Out:
#    database           schema                    name  \
# 0    memory  nps_public_data      multimedia__videos
# 1    memory  nps_public_data            newsreleases
# 2    memory  nps_public_data              park_hours
# 3    memory  nps_public_data             parkinglots
# 4    memory  nps_public_data                   parks
# 5    memory  nps_public_data  passportstamplocations
# 6    memory  nps_public_data                  people
# 7    memory  nps_public_data                  places
# 8    memory  nps_public_data              thingstodo
# 9    memory  nps_public_data                  topics
# 10   memory  nps_public_data           topics__parks
# 11   memory  nps_public_data                   tours
# 12   memory  nps_public_data          visitorcenters
# 13   memory  nps_public_data                 webcams
#
#                                          column_names  \
# 0   [versions, hasOpenCaptions, audioDescribedBuil...
# ...

# %% [markdown]
# ## I Parks

# %%
# %%sql
#
# select * from nps_public_data.parks p limit 5
# Out:
#    relevanceScore               designation  \
# 0               1         National Memorial
# 1               1   National Historic Trail
# 2               1
# 3               1  National Historical Park
# 4               1          Memorial Parkway
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
# 3  Be prepared for hot, humid weather. The histor...
# 4  Summers on the parkway are generally hot and h...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 2  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 4  [{'type': 'Physical', 'line2': '700 George Was...
#
#                                       operatingHours  \
# ...

# %% [markdown]
# ## Campgrounds

# %%
# %%sql
#
# select c.name, c.numberOfSitesFirstComeFirstServe from nps_public_data.campgrounds c
# join nps_public_data.parks as p on p.id = c.parkId
# limit 5;
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nselect c.name, c.numberOfSitesFirstComeFirstServe from nps_public_data.campgrounds c\njoin nps_public_data.parks as p on p.id = c.parkId\nlimit 5;\n')
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%sql
# SELECT
#     p.fullname as park_name,
#     c.name as campground_name
#
# FROM nps_public_data.campgrounds c
# INNER JOIN nps_public_data.parks p
#     ON c.parkcode = p.parkcode
#     AND p.designation = 'National Park'
# WHERE p.name LIKE '%Yosemite%'
# LIMIT 12;
# Out:
#                  park_name              campground_name
# 0   Yosemite National Park  Bridalveil Creek Campground
# 1   Yosemite National Park            Camp 4 Campground
# 2   Yosemite National Park        Crane Flat Campground
# 3   Yosemite National Park    Hodgdon Meadow Campground
# 4   Yosemite National Park    Porcupine Flat Campground
# 5   Yosemite National Park     Tamarack Flat Campground
# 6   Yosemite National Park  Tuolumne Meadows Campground
# 7   Yosemite National Park            Wawona Horse Camp
# 8   Yosemite National Park        White Wolf Campground
# 9   Yosemite National Park    Yosemite Creek Campground
# 10  Yosemite National Park            Wawona Campground
# 11  Yosemite National Park       Lower Pines Campground
